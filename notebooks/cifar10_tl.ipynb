# %%
import os
import tensorflow as tf
import tensorflow_datasets as tfds
import keras
from keras import layers
from matplotlib import pyplot as plt
import numpy as np
# from keras.preprocessing.image import ImageDataGenerator
# Out:
# 2026-02-16 06:44:57.666379: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-16 06:44:57.679228: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-02-16 06:44:57.692741: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8473] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-02-16 06:44:57.696953: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1471] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-16 06:44:57.709625: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
devices=tf.config.experimental.list_physical_devices()
devices
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771224300.324026   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1771224300.433992   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1771224300.434064   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
BATCH_SIZE=64
VAL_SIZE = 10000
RANDOM_SEED=67

tf.random.set_seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)

LABELS = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
    "truck",
]

(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
print("Train shape:", x_train.shape, y_train.shape)
print("Test  shape:", x_test.shape, y_test.shape)
# Out:
# Train shape: (50000, 32, 32, 3) (50000, 1)
# Test  shape: (10000, 32, 32, 3) (10000, 1)

# %%
def visualize_data(x, y, title, n=6):
    idx = np.random.choice(len(x), n, replace=False)

    plt.figure(figsize=(10,4))
    for i, j in enumerate(idx):
        plt.subplot(2,6,i+1)
        plt.imshow(x[j], cmap="gray")
        plt.title(f"{int(y[j])} - {LABELS[int(y[j])]}")
        plt.axis("off")
    plt.suptitle(title)
    plt.show()

visualize_data(x_train, y_train, "CIFAR TRAIN")
visualize_data(x_test,  y_test,  "CIFAR TEST")
# Out:
# /tmp/ipykernel_40840/1377193937.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(f"{int(y[j])} - {LABELS[int(y[j])]}")

# %%
def class_distribution(y, name):
    y = y.reshape(-1)          # (N,1) -> (N,)
    y = y.astype(int)

    counts = np.bincount(y, minlength=10)
    total = len(y)

    print(f"\n{name}")
    for i in range(10):
        print(f"LABEL {i} - {LABELS[i]}: {counts[i]:5d}  ({counts[i]/total:.3f})")
class_distribution(y_train, "TRAIN")
class_distribution(y_test,  "TEST")
# Out:
# TRAIN
# LABEL 0 - airplane:  5000  (0.100)
# LABEL 1 - automobile:  5000  (0.100)
# LABEL 2 - bird:  5000  (0.100)
# LABEL 3 - cat:  5000  (0.100)
# LABEL 4 - deer:  5000  (0.100)
# LABEL 5 - dog:  5000  (0.100)
# LABEL 6 - frog:  5000  (0.100)
# LABEL 7 - horse:  5000  (0.100)
# LABEL 8 - ship:  5000  (0.100)
# LABEL 9 - truck:  5000  (0.100)
#
# TEST
# LABEL 0 - airplane:  1000  (0.100)
# LABEL 1 - automobile:  1000  (0.100)
# LABEL 2 - bird:  1000  (0.100)
# LABEL 3 - cat:  1000  (0.100)
# LABEL 4 - deer:  1000  (0.100)
# LABEL 5 - dog:  1000  (0.100)
# LABEL 6 - frog:  1000  (0.100)
# LABEL 7 - horse:  1000  (0.100)
# LABEL 8 - ship:  1000  (0.100)
# LABEL 9 - truck:  1000  (0.100)

# %%
# Normalize

# x_train = x_train.astype("float32") / 255.0
# x_test  = x_test.astype("float32")  / 255.0

# x_train = x_train.reshape(len(x_train), -1)
# x_test  = x_test.reshape(len(x_test),  -1)

# Labels MUST be integers
y_train = y_train.astype("int32")
y_test  = y_test.astype("int32")

# %%
perm = tf.random.shuffle(tf.range(len(x_train)), seed=RANDOM_SEED)

x_train = tf.gather(x_train, perm)
y_train = tf.gather(y_train, perm)

x_val = x_train[-VAL_SIZE:]
y_val = y_train[-VAL_SIZE:]

x_train = x_train[:-VAL_SIZE]
y_train = y_train[:-VAL_SIZE]

print("Train:", x_train.shape, y_train.shape)
print("Val  :", x_val.shape, y_val.shape)
print("Test :", x_test.shape, y_test.shape)
# Out:
# I0000 00:00:1771224301.330618   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1771224301.330686   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1771224301.330724   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1771224301.476337   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1771224301.476377   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-16 06:45:01.476385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2112] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# I0000 00:00:1771224301.476423   40840 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-02-16 06:45:01.476444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 11062 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 5060 Ti, pci bus id: 0000:01:00.0, compute capability: 12.0
# Train: (40000, 32, 32, 3) (40000, 1)
# Val  : (10000, 32, 32, 3) (10000, 1)
# Test : (10000, 32, 32, 3) (10000, 1)

# %%
# y_train = tf.keras.utils.to_categorical(y_train, 10)
# y_val   = tf.keras.utils.to_categorical(y_val, 10)
# y_test  = tf.keras.utils.to_categorical(y_test, 10)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.shuffle(10000, seed=RANDOM_SEED, reshuffle_each_iteration=True)
train_ds = train_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_ds = val_ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)

test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_ds = test_ds.batch(BATCH_SIZE)
# Out:
# ''+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# +ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85'' is not a recognized feature for this target (ignoring feature)
# +ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target' (ignoring feature)
# +ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)

# %%
base_model = keras.applications.ConvNeXtTiny( include_top=False, weights="imagenet", input_shape=(128, 128, 3), pooling="avg" )
base_model.summary()
# Out:
# Model: "convnext_tiny"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_pres… │ (None, 128, 128,  │          0 │ input_layer[0][0] │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stem  │ (None, 32, 32,    │      4,896 │ convnext_tiny_pr… │
# │ (Sequential)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │      4,800 │ convnext_tiny_st… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │        192 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │     37,248 │ convnext_tiny_st… │
# │ (Dense)             │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │     36,960 │ convnext_tiny_st… │
# │ (Dense)             │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │         96 │ convnext_tiny_st… │
# │ (LayerScale)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ convnext_tiny_st… │
# │                     │ 96)               │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │      4,800 │ add[0][0]         │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │        192 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │     37,248 │ convnext_tiny_st… │
# │ (Dense)             │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │     36,960 │ convnext_tiny_st… │
# │ (Dense)             │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │         96 │ convnext_tiny_st… │
# │ (LayerScale)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ add[0][0],        │
# │                     │ 96)               │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │      4,800 │ add_1[0][0]       │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │        192 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │     37,248 │ convnext_tiny_st… │
# │ (Dense)             │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │     36,960 │ convnext_tiny_st… │
# │ (Dense)             │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │         96 │ convnext_tiny_st… │
# │ (LayerScale)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 32, 32,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ add_1[0][0],      │
# │                     │ 96)               │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_down… │ (None, 16, 16,    │     74,112 │ add_2[0][0]       │
# │ (Sequential)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │      9,600 │ convnext_tiny_do… │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │        384 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │    148,224 │ convnext_tiny_st… │
# │ (Dense)             │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │    147,648 │ convnext_tiny_st… │
# │ (Dense)             │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │        192 │ convnext_tiny_st… │
# │ (LayerScale)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ convnext_tiny_do… │
# │                     │ 192)              │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │      9,600 │ add_3[0][0]       │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │        384 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │    148,224 │ convnext_tiny_st… │
# │ (Dense)             │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │    147,648 │ convnext_tiny_st… │
# │ (Dense)             │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │        192 │ convnext_tiny_st… │
# │ (LayerScale)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 16,    │          0 │ add_3[0][0],      │
# │                     │ 192)              │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │      9,600 │ add_4[0][0]       │
# │ (Conv2D)            │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │        384 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │    148,224 │ convnext_tiny_st… │
# │ (Dense)             │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │    147,648 │ convnext_tiny_st… │
# │ (Dense)             │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │        192 │ convnext_tiny_st… │
# │ (LayerScale)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 16, 16,    │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 16, 16,    │          0 │ add_4[0][0],      │
# │                     │ 192)              │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_down… │ (None, 8, 8, 384) │    295,680 │ add_5[0][0]       │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ convnext_tiny_do… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 8, 8, 384) │          0 │ convnext_tiny_do… │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_6[0][0]       │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 8, 8, 384) │          0 │ add_6[0][0],      │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_7[0][0]       │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 8, 8, 384) │          0 │ add_7[0][0],      │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_8[0][0]       │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 8, 8, 384) │          0 │ add_8[0][0],      │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_9[0][0]       │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 8, 8, 384) │          0 │ add_9[0][0],      │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_10[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 8, 8, 384) │          0 │ add_10[0][0],     │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_11[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 8, 8, 384) │          0 │ add_11[0][0],     │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_12[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 8, 8, 384) │          0 │ add_12[0][0],     │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │     19,200 │ add_13[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        768 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │    591,360 │ convnext_tiny_st… │
# │ (Dense)             │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 1536)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │    590,208 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │        384 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 8, 8, 384) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 8, 8, 384) │          0 │ add_13[0][0],     │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_down… │ (None, 4, 4, 768) │  1,181,184 │ add_14[0][0]      │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │     38,400 │ convnext_tiny_do… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │      1,536 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4,      │  2,362,368 │ convnext_tiny_st… │
# │ (Dense)             │ 3072)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 3072)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │  2,360,064 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │        768 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 4, 4, 768) │          0 │ convnext_tiny_do… │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │     38,400 │ add_15[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │      1,536 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4,      │  2,362,368 │ convnext_tiny_st… │
# │ (Dense)             │ 3072)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 3072)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │  2,360,064 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │        768 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 4, 4, 768) │          0 │ add_15[0][0],     │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │     38,400 │ add_16[0][0]      │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │      1,536 │ convnext_tiny_st… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4,      │  2,362,368 │ convnext_tiny_st… │
# │ (Dense)             │ 3072)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4,      │          0 │ convnext_tiny_st… │
# │ (Activation)        │ 3072)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │  2,360,064 │ convnext_tiny_st… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │        768 │ convnext_tiny_st… │
# │ (LayerScale)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ convnext_tiny_stag… │ (None, 4, 4, 768) │          0 │ convnext_tiny_st… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 4, 4, 768) │          0 │ add_16[0][0],     │
# │                     │                   │            │ convnext_tiny_st… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ add_17[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 768)       │      1,536 │ global_average_p… │
# │ (LayerNormalizatio… │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,820,128 (106.13 MB)
#  Trainable params: 27,820,128 (106.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
inputs = keras.Input(shape=(32,32,3), name="input_image")

x = keras.layers.Resizing(128,128)(inputs)

# Correct preprocessing for EfficientNetV2
# x = keras.layers.Lambda(
#     keras.applications.efficientnet.preprocess_input
# )(x)

# Backbone (keep BN frozen in phase 1)
x = base_model(x, training=False)

# Custom classification head
x = keras.layers.Dense(512, activation="relu")(x)
x = keras.layers.BatchNormalization()(x)
x = keras.layers.Dropout(0.4)(x)
x = keras.layers.Dense(256, activation="relu")(x)
x = keras.layers.BatchNormalization()(x)

outputs = keras.layers.Dense(10, activation="softmax", name="predictions")(x)

model = keras.Model(inputs, outputs, name="CIFAR10_ConvNextTiny")
model.summary()
# Out:
# Model: "CIFAR10_ConvNextTiny"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resizing (Resizing)             │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ convnext_tiny (Functional)      │ (None, 768)            │    27,820,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       393,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,350,826 (108.15 MB)
#  Trainable params: 28,349,290 (108.14 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(3e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

# %%
model.summary()
# Out:
# Model: "CIFAR10_ConvNextTiny"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_image (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resizing (Resizing)             │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ convnext_tiny (Functional)      │ (None, 768)            │    27,820,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       393,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,350,826 (108.15 MB)
#  Trainable params: 28,349,290 (108.14 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
class MetricsStopping(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}

        acc = logs.get("accuracy")
        val_acc = logs.get("val_accuracy")

        if acc is None or val_acc is None:
            return

        if acc > 0.95 and val_acc > 0.95 and acc >= val_acc:
            print(
                f"\n\nSufficient Metrics Reached! "
                f"acc={acc:.3f}, val_acc={val_acc:.3f}\n"
            )
            self.model.stop_training = True


reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor  = "val_loss",
    factor   = 0.5,
    patience = 2,
    min_lr   = 1e-7,
    verbose  = 1,
)

# %%
print("Fit model on training data")
history = model.fit(
    train_ds,
    epochs=10,
    validation_data=val_ds,
    callbacks=[MetricsStopping(),reduce_lr]
)
# Out:
# Fit model on training data
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771224330.488956   41206 service.cc:146] XLA service 0x7a5e20014010 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771224330.488989   41206 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 5060 Ti, Compute Capability 12.0
# 2026-02-16 06:45:31.033981: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-16 06:45:32.891585: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 90701
# E0000 00:00:1771224336.007341   41206 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1771224336.164096   41206 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1771224336.313306   41206 gpu_timer.cc:183] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# 2026-02-16 06:45:45.038933: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:393] ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_67', 120 bytes spill stores, 120 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_64', 176 bytes spill stores, 176 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'loop_add_subtract_fusion_49', 88 bytes spill stores, 88 bytes spill loads
#
# I0000 00:00:1771224345.145956   41206 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8658 - loss: 0.4366
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# '+ptx85' is not a recognized feature for this target (ignoring feature)
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 106s 103ms/step - accuracy: 0.8658 - loss: 0.4363 - val_accuracy: 0.9608 - val_loss: 0.1286 - learning_rate: 3.0000e-04
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.9749 - loss: 0.0779 - val_accuracy: 0.9576 - val_loss: 0.1465 - learning_rate: 3.0000e-04
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9837 - loss: 0.0527
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 59s 95ms/step - accuracy: 0.9837 - loss: 0.0527 - val_accuracy: 0.9550 - val_loss: 0.1646 - learning_rate: 3.0000e-04
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.9934 - loss: 0.0191 - val_accuracy: 0.9728 - val_loss: 0.1047 - learning_rate: 1.5000e-04
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 59s 95ms/step - accuracy: 0.9987 - loss: 0.0050 - val_accuracy: 0.9742 - val_loss: 0.1039 - learning_rate: 1.5000e-04
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 0.9983 - loss: 0.0059 - val_accuracy: 0.9654 - val_loss: 0.1451 - learning_rate: 1.5000e-04
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9948 - loss: 0.0170
# Epoch 7: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.9948 - loss: 0.0170 - val_accuracy: 0.9720 - val_loss: 0.1156 - learning_rate: 1.5000e-04
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9764 - val_loss: 0.1011 - learning_rate: 7.5000e-05
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 96ms/step - accuracy: 0.9999 - loss: 7.7544e-04 - val_accuracy: 0.9769 - val_loss: 0.1034 - learning_rate: 7.5000e-05
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 2.7274e-04
# Epoch 10: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 60s 95ms/step - accuracy: 1.0000 - loss: 2.7267e-04 - val_accuracy: 0.9788 - val_loss: 0.1029 - learning_rate: 7.5000e-05

# %%
import matplotlib.pyplot as plt

acc      = history.history['accuracy']
val_acc  = history.history['val_accuracy']
loss     = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(epochs_range, acc, label="Training Accuracy")
plt.plot(epochs_range, val_acc, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Accuracy")

# Loss
plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label="Training Loss")
plt.plot(epochs_range, val_loss, label="Validation Loss")
plt.legend(loc="upper right")
plt.title("Loss")

plt.show()

# %%
test_loss, test_acc = model.evaluate(test_ds)
print("Test accuracy:", test_acc)
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9757 - loss: 0.1195
# Test accuracy: 0.9761999845504761

# %%
from sklearn.metrics import confusion_matrix


def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
y_pred_probs = model.predict(test_ds)          
y_pred = np.argmax(y_pred_probs, axis=1)       
y_true = y_test.reshape(-1)                    

plot_confusion_matrix(y_true, y_pred, classes=LABELS)
plt.show()

plot_confusion_matrix(y_true, y_pred, classes=LABELS, normalize=True)
plt.show()
# Out:
#   1/157 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step
# Confusion matrix, without normalization
# Normalized confusion matrix

# %%
# model.save("mymodel.h5")
